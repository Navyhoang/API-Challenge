# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
! pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\navyh\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\navyh\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
from random import sample
import os
import csv
from pprint import pprint

# Import API key
import api_keys
from api_keys import api_key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
unique_cities = len(cities)
print(f"From 1500 sets of lats and lngs, there are {unique_cities} unique cities" )
# Out:
# From 1500 sets of lats and lngs, there are 611 unique cities

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Grab 500 random cities from unique cities list above
city_sample = sample(cities,500)
city_sample
# Out:
# ['souillac',
#  'mrirt',
#  'lebu',
#  'bambanglipuro',
#  'ontario',
#  'bilma',
#  'urdzhar',
#  'soyo',
#  'puerto quijarro',
#  'simeykyne',
#  'bolungarvik',
#  'pevek',
#  'sale',
#  'alyangula',
#  'sogdiondon',
#  'gotsu',
#  'vardo',
#  'torbay',
#  'dalvik',
#  'sisimiut',
#  'guaymas',
#  'elko',
#  'lhuntshi',
#  'rawson',
#  'huari',
#  'riberalta',
#  'marawi',
#  'new norfolk',
#  'luwuk',
#  'grand river south east',
#  'brighton',
#  'ossora',
#  'shelburne',
#  'jiddah',
#  'ploemeur',
#  'louisbourg',
#  'seoul',
#  'natal',
#  'paramonga',
#  'vila velha',
#  'troitsko-pechorsk',
#  'sheopur',
#  'tocopilla',
#  'omsukchan',
#  'sistranda',
#  'marcona',
#  'grand gaube',
#  'georgetown',
#  'oktyabrskoye',
#  'dunedin',
#  'arlit',
#  'svarstad',
#  'taga',
#  'kirgiz-miyaki',
#  'angul',
#  'labuan',
#  'scarborough',
#  'santa isabel do rio negro',
#  'saleaula',
#  'boa vista',
#  'longyearbyen',
#  'wajir',
#  'camopi',
#  'alad',
#  'opuwo',
#  'coahuayana',
#  'clyde river',
#  'namatanai',
#  'rikitea',
#  'horodyshche',
#  'codrington',
#  'camana',
#  'svetlogorsk',
#  'tortoli',
#  'coihaique',
#  'zhezkazgan',
#  'pokhara',
#  'atlantic city',
#  'quatre cocos',
#  'egvekinot',
#  'berlevag',
#  'coachella',
#  'birjand',
#  'pervomayskoye',
#  'formia',
#  'moriyama',
#  'kulhudhuffushi',
#  'sorong',
#  'yamada',
#  'saint anthony',
#  'ginda',
#  'worland',
#  'chifeng',
#  'homer',
#  'sherbakul',
#  'sinnamary',
#  'hamamatsu',
#  'muisne',
#  'svetlaya',
#  'nixa',
#  'las vegas',
#  'manzanillo',
#  'bayeux',
#  'fershampenuaz',
#  'laramie',
#  'manisa',
#  'springbok',
#  'umzimvubu',
#  'teguldet',
#  'port said',
#  'ajdabiya',
#  'asau',
#  'hirara',
#  'ribeira grande',
#  'verkhnyaya inta',
#  'orsha',
#  'hualmay',
#  'pedernales',
#  'okhotsk',
#  'nyurba',
#  'tidore',
#  'pilot butte',
#  'fort saint james',
#  'gimli',
#  'saint-francois',
#  'sao joao da barra',
#  'krasnovishersk',
#  'kismayo',
#  'ishigaki',
#  'mys shmidta',
#  'byron bay',
#  'yellowknife',
#  'grindavik',
#  'nha trang',
#  'buala',
#  'macamic',
#  'severo-yeniseyskiy',
#  'seybaplaya',
#  'abu samrah',
#  'kapaa',
#  'cururupu',
#  'hobyo',
#  'kviteseid',
#  'vao',
#  'mahebourg',
#  'bosaso',
#  'bundaberg',
#  'mattru',
#  'sirjan',
#  'cuamba',
#  'nata',
#  'san quintin',
#  'bull savanna',
#  'poyarkovo',
#  'melo',
#  'taltal',
#  'maniitsoq',
#  'buritizeiro',
#  'ihosy',
#  'la grande',
#  'brebes',
#  'port blair',
#  'masuguru',
#  'manaus',
#  'viedma',
#  'goderich',
#  'nuuk',
#  'mehamn',
#  'isfana',
#  'port elizabeth',
#  'praya',
#  'mitsamiouli',
#  'lufilufi',
#  'victoria',
#  'thinadhoo',
#  'henties bay',
#  'te anau',
#  'balakirevo',
#  'ban nahin',
#  'nyuksenitsa',
#  'sentyabrskiy',
#  'kodinar',
#  'huarmey',
#  'kavieng',
#  'wanning',
#  'bealanana',
#  'bethel',
#  'caluquembe',
#  'coaldale',
#  'mumford',
#  'namibe',
#  'saryshagan',
#  'whyalla',
#  'karamay',
#  'tarko-sale',
#  'harper',
#  'roald',
#  'tefe',
#  'pringsewu',
#  'lorengau',
#  'deputatskiy',
#  'bitung',
#  'shillong',
#  'bambous virieux',
#  'trogir',
#  'flin flon',
#  'dikson',
#  'artyk',
#  'westport',
#  'desterro',
#  'narsaq',
#  'arsenyev',
#  'eskasem',
#  'gemena',
#  'vestmannaeyjar',
#  'amderma',
#  'kaeo',
#  'kruisfontein',
#  'lompoc',
#  'kaspiyskiy',
#  'maghama',
#  'ekhabi',
#  'puerto escondido',
#  'sabha',
#  'hay river',
#  'moose factory',
#  'east london',
#  'sitka',
#  'acapulco',
#  'thompson',
#  'jamestown',
#  'hithadhoo',
#  'maunabo',
#  'illoqqortoormiut',
#  'hasaki',
#  'cockburn town',
#  'atuona',
#  'conde',
#  'abha',
#  'mahajanga',
#  'ambon',
#  'harrisburg',
#  'sinait',
#  'salalah',
#  'babino',
#  'ust-kamchatsk',
#  'la ronge',
#  'hermanus',
#  'katherine',
#  'tiksi',
#  'siderno',
#  'krasnoselkup',
#  'dera ghazi khan',
#  'busselton',
#  'new ulm',
#  'chagda',
#  'taolanaro',
#  'fairbanks',
#  'miri',
#  'batsfjord',
#  'kankan',
#  'geraldton',
#  'quelimane',
#  'aragarcas',
#  'boende',
#  'umtata',
#  'neryungri',
#  'carnarvon',
#  'accra',
#  'yulara',
#  'kalmunai',
#  'fenoarivo',
#  'paonta sahib',
#  'mbekenyera',
#  'cidreira',
#  'belmonte',
#  'ovre ardal',
#  'baykit',
#  'klaksvik',
#  'husavik',
#  'leh',
#  'nara',
#  'attawapiskat',
#  'sibolga',
#  'belyy yar',
#  'saldanha',
#  'belushya guba',
#  'palabuhanratu',
#  'shimoda',
#  'edendale',
#  'spokane',
#  'itoman',
#  'katsuura',
#  'morgan city',
#  'butaritari',
#  'yar-sale',
#  'kloulklubed',
#  'pochutla',
#  'arrifes',
#  'jeremoabo',
#  'pisco',
#  'kaitangata',
#  'umm lajj',
#  'tuktoyaktuk',
#  'porto novo',
#  'punta arenas',
#  'xichang',
#  'mareeba',
#  'ostrovnoy',
#  'camacha',
#  'naze',
#  'north bend',
#  'leshukonskoye',
#  'kakonko',
#  'sao jose da coroa grande',
#  'tuatapere',
#  'nouadhibou',
#  'beringovskiy',
#  'vostok',
#  'mount gambier',
#  'turan',
#  'meulaboh',
#  'miles city',
#  'sioux lookout',
#  'burgeo',
#  'kasba',
#  'kasulu',
#  'fare',
#  'chuy',
#  'auki',
#  'guerrero negro',
#  'colotlan',
#  'mabaruma',
#  'avera',
#  'mar del plata',
#  'castro',
#  'san patricio',
#  'samusu',
#  'limache',
#  'ponta do sol',
#  'jetis',
#  'apaxtla',
#  'pinheiro',
#  'harkany',
#  'batagay',
#  'baiyin',
#  'lakes entrance',
#  'manokwari',
#  'jiayuguan',
#  'aswan',
#  'pangkalanbuun',
#  'chimbote',
#  'lagoa',
#  'rocha',
#  'palu',
#  'chizhou',
#  'mizdah',
#  'norman wells',
#  'toora-khem',
#  'lubao',
#  'lovozero',
#  'marsh harbour',
#  'minot',
#  'utiroa',
#  'kutum',
#  'banda aceh',
#  'severo-kurilsk',
#  'skibbereen',
#  'port lincoln',
#  'cherskiy',
#  'goundi',
#  'comarapa',
#  'nome',
#  'margate',
#  'sur',
#  'xining',
#  'avarua',
#  'tasiilaq',
#  'gryazovets',
#  'kodiak',
#  'pandan',
#  'faanui',
#  'albany',
#  'chokurdakh',
#  'touros',
#  'kavaratti',
#  'rassvet',
#  'raga',
#  'barentsburg',
#  'broken hill',
#  'puerto ayora',
#  'piacabucu',
#  'iqaluit',
#  'tessalit',
#  'cayenne',
#  'kadirli',
#  'cape town',
#  'sanmihaiul-almasului',
#  'waipawa',
#  'hilo',
#  'gornopravdinsk',
#  'pueblo nuevo',
#  'juneau',
#  'ust-bolsheretsk',
#  'barra do garcas',
#  'lasa',
#  'ambilobe',
#  'karratha',
#  'mataura',
#  'gelemso',
#  'fortuna',
#  'port alfred',
#  'raipur',
#  'vallenar',
#  'nguiu',
#  'ardakan',
#  'bandarbeyla',
#  'hobart',
#  'yerbogachen',
#  'luderitz',
#  'gondal',
#  'ganzhou',
#  'fiche',
#  'valladolid',
#  'ayan',
#  'beaverlodge',
#  'ongandjera',
#  'salacgriva',
#  'salta',
#  'jiwani',
#  'srivardhan',
#  'linjiang',
#  'gigmoto',
#  'mbaiki',
#  'san andres',
#  'buluang',
#  'champerico',
#  'dingle',
#  'qaanaaq',
#  'darnah',
#  'gat',
#  'diamantino',
#  'airai',
#  'ilulissat',
#  'tynda',
#  'krutinka',
#  'los llanos de aridane',
#  'poum',
#  'chapais',
#  'tilichiki',
#  'nikolskoye',
#  'fuzhou',
#  'tres picos',
#  'hamilton',
#  'nenjiang',
#  'tual',
#  'gamboma',
#  'talnakh',
#  'carndonagh',
#  'ariquemes',
#  'esperance',
#  'hayden',
#  'san cristobal',
#  'alofi',
#  'kuche',
#  'pasighat',
#  'churapcha',
#  'san carlos de bariloche',
#  'bluff',
#  'huayucachi',
#  'wajima',
#  'hutchinson',
#  'nizhneyansk',
#  'oistins',
#  'olinda',
#  'constitucion',
#  'lolua',
#  'srednekolymsk',
#  'korla',
#  'laje',
#  'launceston',
#  'asyut',
#  'falealupo',
#  'sabang',
#  'mananjary',
#  'bengkulu',
#  'cabo san lucas',
#  'provideniya',
#  'barrow',
#  'bredasdorp',
#  'isangel',
#  'polewali',
#  'mushie',
#  'ngukurr',
#  'ancud',
#  'saint-philippe',
#  'afua',
#  'iseyin',
#  'asfi',
#  'ulaangom']

# %%
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).
# api.openweathermap.org/data/2.5/forecast/daily?q={city name}&cnt={cnt}&appid={API key}

# Daily Forecast 16 days
# base_url = "https://api.openweathermap.org/data/2.5/forecast/daily?"

# city ='alabama'
# cnt = 1
# units = 'Imperial'

# final_url = f"{base_url}q={city}&cnt={cnt}&units={units}&appid={api_key}"
# response = requests.get(final_url).json()


city_name = []
city_ID = []
city_lat = []
city_lngs = []
city_temp_F = []
city_humidity = []
city_cloudiness = []
city_windspeed = []

# Current Weather API

for city in city_sample:

    base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
    final_url = base_url + api_key + "&q=" + city
    response = requests.get(final_url).json()

    city_name.append(response["name"])
    city_ID.append(response["id"])
    city_lat.append(response["coord"]["lat"])
    city_lngs.append(response["coord"]["lon"])
    city_temp_F.append(response["main"]["temp"])
    city_humidity.append(response["main"]["humidity"])
    city_cloudiness.append(response["clouds"]["all"])
    city_windspeed.append(response["wind"]["speed"])

sample_df = pd.DataFrame({
                "City": city_name,
                "ID": city_ID,
                "Lat": city_ID,
                "Lon": city_ID,
                "Temp": city_ID,
                "Humidity": city_ID,
                "Cloudiness": city_ID,
                "Wind Speed": city_ID

})

sample_df
# Out:
#           City       ID      Lat      Lon     Temp  Humidity  Cloudiness  \
# 0    Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
# 1    Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
# 2    Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
# 3    Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
# 4    Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
# ..         ...      ...      ...      ...      ...       ...         ...
# 495  Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
# 496  Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
# 497  Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
# 498  Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
# 499  Las Vegas  5506956  5506956  5506956  5506956   5506956     5506956
#
#      Wind Speed
# 0       5506956
# 1       5506956
# 2       5506956
# 3       5506956
# 4       5506956
# ..          ...
# 495     5506956
# 496     5506956
# 497     5506956
# 498     5506956
# 499     5506956
#
# [500 rows x 8 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
sample_df = pd.DataFrame({
                "City": city_sample})

sample_df

# %%
# Write dataframe to a csv file and skip the header row
sample_df.to_csv("Random Samples.csv", index=False, header=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
